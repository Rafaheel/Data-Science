# %% [markdown]
# # Métodos de Linhas e Colunas
#
# Manipulando dados com codificação de texto

# %%
import numpy as no
import pandas as pd

# %%
file = "C:\\Users\Rafael\\Desktop\\Data-Science\\Métodos de Linhas e Colunas\\Diarias.csv"
diarias = pd.read_csv(file, encoding = 'latin-1', sep = "\t")
diarias.head(5)
# Out:
#    Código Órgão Superior       Nome Órgão Superior  Código Órgão Subordinado  \
# 0                  20000  PRESIDENCIA DA REPUBLICA                     20101
# 1                  20000  PRESIDENCIA DA REPUBLICA                     20101
# 2                  20000  PRESIDENCIA DA REPUBLICA                     20101
# 3                  20000  PRESIDENCIA DA REPUBLICA                     20101
# 4                  20000  PRESIDENCIA DA REPUBLICA                     20101
#
#      Nome Órgão Subordinado  Código Unidade Gestora  \
# 0  PRESIDENCIA DA REPUBLICA                  110001
# 1  PRESIDENCIA DA REPUBLICA                  110001
# 2  PRESIDENCIA DA REPUBLICA                  110001
# 3  PRESIDENCIA DA REPUBLICA                  110001
# 4  PRESIDENCIA DA REPUBLICA                  110001
#
#              Nome Unidade Gestora  Código Função    Nome Função  \
# 0  SECRETARIA DE ADMINISTRACAO/PR              4  Administração
# ...

# %%
type(diarias)
# Out:
# pandas.core.frame.DataFrame

# %%
diarias.shape
# Out:
# (38745, 21)

# %%
diarias.dtypes
# Out:
# Código Órgão Superior        int64
# Nome Órgão Superior         object
# Código Órgão Subordinado     int64
# Nome Órgão Subordinado      object
# Código Unidade Gestora       int64
# Nome Unidade Gestora        object
# Código Função                int64
# Nome Função                 object
# Código Subfunção             int64
# Nome Subunção               object
# Código Programa              int64
# Nome Programa               object
# Código Ação                 object
# Nome Ação                   object
# Linguagem Cidadã            object
# CPF Favorecido              object
# Nome Favorecido             object
# Documento Pagamento         object
# Gestão Pagamento             int64
# Data Pagamento              object
# Valor Pagamento             object
# dtype: object

# %%
diarias.describe()
# Out:
#        Código Órgão Superior  Código Órgão Subordinado  \
# count           38745.000000              38745.000000
# mean            33351.612879              33977.357001
# std             11688.707029              10507.438694
# min             20000.000000              20101.000000
# 25%             26000.000000              26258.000000
# 50%             26000.000000              30107.000000
# 75%             40000.000000              39902.000000
# max             56000.000000              91005.000000
#
#        Código Unidade Gestora  Código Função  Código Subfunção  \
# count            38745.000000   38745.000000      38745.000000
# mean            237246.130081      11.335527        272.743812
# std             140440.626806       6.201929        168.209653
# min             110001.000000       2.000000         31.000000
# 25%             153163.000000       6.000000        122.000000
# 50%             170092.000000      12.000000        182.000000
# ...

# %%
#bascamante, os métodos podem receber argumentos. Para saber quais são os metodos, posicione o cursor entre os parenteses e pressione shift + tab
diarias.describe(include=['object'])
diarias.describe()
# Out:
#            Nome Órgão Superior               Nome Órgão Subordinado  \
# count                    38745                                38745
# unique                      22                                  224
# top     MINISTERIO DA EDUCACAO  INSTITUTO NACIONAL DO SEGURO SOCIAL
# freq                     10048                                 3763
#
#                          Nome Unidade Gestora Nome Função  \
# count                                   38745       38745
# unique                                   1454          25
# top     DIVISAO DE DIARIAS E PASSAGENS DA AGU    Educação
# freq                                      663       10045
#
#               Nome Subunção                     Nome Programa Código Ação  \
# count                 38745                             38745       38745
# unique                   69                                76         308
# top     Administração Geral  Educação de qualidade para todos        2000
# ...

# %%
file2 = "C:\\Users\\Rafael\\Desktop\\Data-Science\\Métodos de Linhas e Colunas\\movies.csv"
filmes= pd.read_csv(file2)
filmes.head()
# Out:
#    star rating                     title content rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
filmes.columns
# Out:
# Index(['star rating', 'title', 'content rating', 'genre', 'duration',
#        'actors list'],
#       dtype='object')

# %%
# Mudando nomes das colunas para o dot notation. (Para o pandas é preciso explicitar para que a coluna seja realmente alterada, 
#assim usaremos o metodo )
filmes.rename(columns = {'star rating':'star_rating','content rating':'content_rating'}, inplace=True)

# %%
filmes.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors list'],
#       dtype='object')

# %% [markdown]
# # Real World
#
# É muito comum termos arquivos com várias colunas e a operação de renomear uma a uma fica inviável. Podemos então, utilizar funções do Python para trabalharmos com as colunas.

# %%
file3 = "C:\\Users\\Rafael\\Desktop\\Data-Science\\Métodos de Linhas e Colunas\\movies.csv"
filmes2 = pd.read_csv(file3)
filmes2.head

filmes2.columns = filmes.columns.str.replace(" ","_")
filmes2.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
#Por boa prática, ao realizar alguma alteração no Dataframe, devemos atribuir a outra variável,
#assim é possível rastrear as mudanças e também voltar ao último passo.
#Aqui também podemos utilizar o inplace=True

#Axis = 1 - Colunas / Axis = 0 - Linhas

#Filmes01 - foi criado sem a coluna content_rating

filmes3 = filmes.drop(['content_rating'], axis=1)
filmes3.head()

#Para remover mais de uma coluna passar o nome das colunas entre {}
# Out:
#    star_rating                     title   genre  duration  \
# 0          9.3  The Shawshank Redemption   Crime       142
# 1          9.2             The Godfather   Crime       175
# 2          9.1    The Godfather: Part II   Crime       200
# 3          9.0           The Dark Knight  Action       152
# 4          8.9              Pulp Fiction   Crime       154
#
#                                          actors list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# # Removendo Linhas do Dataframe

# %%
filmes2.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
filmes4 = filmes2.drop([0,1], axis=0)
filmes4
